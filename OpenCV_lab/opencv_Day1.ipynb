# %%
720*480
# Out:
# 345600

# %%
#pip install opencv-contrib-python
#pip install caer

# %%
from matplotlib import pyplot as plt

# %%
import cv2 as cv2
img = cv2.imread('Resources/Photos/cats.jpg')
cv2.imshow('cats', img)
cv2.waitKey(0)
# Out:
# -1

# %%
img = cv2.imread('Resources/Photos/cats.jpg', 0)
print(img.shape)
plt.imshow(img)
plt.colorbar()
# Out:
# (428, 640)

# %%
print(type(img))
print(img.dtype)
# Out:
# <class 'numpy.ndarray'>
# uint8

# %%
plt.imshow(img[160:280, 100:480])

# %%
vals = img
# plt.imshow(vals)
# plt.imshow(vals[0:50, 0:240])

vals[0:100, 0:600] = 255
plt.imshow(vals)

# %%
plt.hist(img.ravel(), 256, [0, 256])
# Out:
# (array([9.580e+02, 2.610e+02, 3.360e+02, 3.260e+02, 3.710e+02, 4.610e+02,
#         4.900e+02, 5.600e+02, 5.790e+02, 6.750e+02, 7.190e+02, 7.580e+02,
#         7.850e+02, 8.190e+02, 8.580e+02, 7.310e+02, 7.920e+02, 7.910e+02,
#         8.130e+02, 8.400e+02, 8.180e+02, 8.900e+02, 9.310e+02, 9.870e+02,
#         1.078e+03, 1.047e+03, 1.201e+03, 1.256e+03, 1.441e+03, 1.568e+03,
#         1.747e+03, 1.782e+03, 1.955e+03, 1.927e+03, 2.083e+03, 2.241e+03,
#         2.320e+03, 2.328e+03, 2.331e+03, 2.522e+03, 2.594e+03, 2.590e+03,
#         2.683e+03, 2.609e+03, 2.740e+03, 2.733e+03, 2.734e+03, 2.676e+03,
#         2.670e+03, 2.635e+03, 2.751e+03, 2.708e+03, 2.768e+03, 2.760e+03,
#         2.720e+03, 2.767e+03, 2.790e+03, 2.659e+03, 2.546e+03, 2.593e+03,
#         2.536e+03, 2.568e+03, 2.528e+03, 2.525e+03, 2.487e+03, 2.360e+03,
#         2.450e+03, 2.455e+03, 2.476e+03, 2.460e+03, 2.378e+03, 2.289e+03,
#         2.290e+03, 2.143e+03, 2.114e+03, 2.031e+03, 1.948e+03, 1.746e+03,
# ...

# %%
import cv2 as cv2
vid = cv2.VideoCapture('Resources/Videos/dog.mp4')
while(vid.isOpened()):
    ret, frame = vid.read()
    if ret:
        frameresize = Rescale_Frames(frame)
        cv2.imshow('frame', frame)
        cv2.imshow('resized frame', frameresize)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
vid.release()
cv2.destroyAllWindows()

# %%
def Rescale_Frames(frame, scale=0.25):
    width = int(frame.shape[1]*scale)
    height = int(frame.shape[0]*scale)
    dimensions = (width, height)
    return cv2.resize(frame, dimensions, interpolation = cv2.INTER_CUBIC)

# %%
import cv2 as cv2
vid = cv2.VideoCapture(0)
while(vid.isOpened()):
    ret, frame = vid.read()
    if ret:
        frameresize = Rescale_Frames(frame)
        cv2.imshow('frame', frame)
        cv2.imshow('resized frame', frameresize)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
vid.release()
cv2.destroyAllWindows()
